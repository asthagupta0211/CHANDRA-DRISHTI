# %% [markdown]
# # Chandra Drishti AI - Free Cloud Server Deployment
# This notebook runs your heavy AI model on Google's powerful servers (with 12GB of RAM) completely for free.
# It will generate a live public URL for you to share.

# %%
# 1. Download your code
# !git clone https://github.com/asthagupta0211/CHANDRA-DRISHTI.git
# %cd CHANDRA-DRISHTI/backend

# 2. Install dependencies
# !pip install -r requirements.txt
# !npm install -g localtunnel

import urllib
print("Password/Enpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

# %%
# 3. Run the Server and Tunnel
# !nohup python server.py & 
# !lt --port 5000
